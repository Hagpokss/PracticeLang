# %% [markdown]
# ##This is a sample of H1 Heading
#
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**
# * List popular languages for Data Scientists
# * List commonly used libraries by Data Scientists
# * List commonly used open source Data Science Tools

# %% [markdown]
# Some of the popular languages that Data Scientests user are:
# 1. Python
# 2. Java
# 3. C
# 4. C++

# %% [markdown]
# Some of the commonly used libraries by Data Scientests include:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# Data Science Tools
# ------------------
# JupyterLab
# VSCode
# RStudio

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This will convert 200 minutes to hours by dividing 60

200/60
# Out:
# 3.3333333333333335

# %%
# This is a simple arithmetic to multiply then add integers

(3*4)+5
# Out:
# 17
